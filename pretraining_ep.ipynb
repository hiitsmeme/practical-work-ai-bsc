# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,TensorDataset
import numpy as np
import random
import json
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import roc_auc_score, auc, precision_recall_curve

# %%
data = np.load('./data/data_scaled.npz')
X_train = data['X_train']
y_train = data['y_train']
X_val = data['X_val']
y_val = data["y_val"]
X_test = data['X_test']
y_test = data['y_test']

# %%
# function to calculate embeddings for model input
def embedding_propagation(X, alpha):
    # squared distances
    sq = torch.sum(X ** 2, dim=1, keepdim=True)  # shape: (num_samples, 1)
    distances_squared = sq + sq.t() - 2 * (X @ X.t())
    
    # adjacency matrix
    sigma2 = torch.var(distances_squared)
    A = torch.exp(-distances_squared / sigma2)
    A.fill_diagonal_(0)
    
    # diagonal matrix
    row_sums = torch.sum(A, dim=1)
    D12 = torch.diag(1 / torch.sqrt(row_sums))
    
    # laplacian matrix
    L = D12 @ A @ D12
    
    # propagator matrix
    num_samples = X.shape[0]
    I = torch.eye(num_samples, device=X.device, dtype=X.dtype)
    P = torch.inverse(I - alpha * L)
    
    # final embeddings
    X_final = P @ X
    
    return X_final

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size, dropout_rates=[0.5,0.25]):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_sizes[0])
        self.fc2 = nn.Linear(hidden_sizes[0], hidden_sizes[1])
        self.fc3 = nn.Linear(hidden_sizes[1], output_size)

        self.relu = nn.ReLU()
        self.input_dropout = nn.Dropout(dropout_rates[0])
        self.hidden_dropout = nn.Dropout(dropout_rates[1])

    def forward(self, x):
        x = self.input_dropout(x)
        x = self.relu(self.fc1(x))
        x = self.hidden_dropout(x)
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def getPrAucIndividualClass(train_or_val, all_labels, all_preds, writer, epoch):
    # stack label arrays vertically
    all_labels = np.vstack(all_labels)
    all_preds = np.vstack(all_preds)
    # convert them to torch, for gpu compatibility
    all_labels = torch.tensor(all_labels)
    all_preds = torch.tensor(all_preds)
    all_pr_auc = []
    all_roc_auc = []
    # loop over 9 tasks
    for class_idx in range(all_labels.shape[1]):
        mask = ~torch.isnan(all_labels[:, class_idx])   # mask out NaN values
        class_labels = all_labels[:,class_idx][mask]    # get labels for current class
        class_preds = all_preds[:,class_idx][mask]      # get model preds for current class
        baseline = class_labels.mean()      # baseline is portion of pos labels
        # calculate scores
        roc_auc = roc_auc_score(class_labels, class_preds)
        precision, recall, _ = precision_recall_curve(class_labels, class_preds)
        pr_auc = auc(recall, precision) - baseline
        # save scores
        all_pr_auc.append(pr_auc)
        all_roc_auc.append(roc_auc)

        # log to tensorboard
        # writer.add_pr_curve(f"{train_or_val} Precision-Recall Class {class_idx}", class_labels, class_preds, epoch)
        # writer.add_scalar(f"{train_or_val} PR-AUC Class {class_idx}", pr_auc, epoch)
        # writer.add_scalar(f"{train_or_val} ROC-AUC Class {class_idx}", roc_auc, epoch)

    # return metrics averaged over tasks and not averaged over tasks
    return np.mean(np.array(all_pr_auc)), np.mean(np.array(all_roc_auc)), np.array(all_pr_auc), np.array(all_roc_auc)

# %%
def masked_bce_loss(outputs, targets):
    mask = ~torch.isnan(targets)  # Create a mask where values are NOT NaN
    loss = nn.functional.binary_cross_entropy_with_logits(outputs[mask], targets[mask])  # Compute loss only on valid labels
    return loss

# %%
def save_best_model(model, avg_pr_auc, best_score, file_path):
    # Check if the current average PR AUC is better than the best recorded score
    if avg_pr_auc > best_score:
        torch.save(model.state_dict(), file_path)
        print(f"Saved new best model with avg PR AUC: {avg_pr_auc:.4f}")
        return True
    else:
        print(f"Current avg PR AUC: {avg_pr_auc:.4f} did not improve over best score: {best_score:.4f}")
        return False

# %%
# Function to train the model
def train_model(model, train_loader, val_loader, criterion, optimizer, device, writer, num_epochs=10, alpha=0.8):
    model.to(device)
    best_score = 0
    file_path = "best_model.pth"
    for epoch in range(num_epochs):
        # ------------- TRAINING ------------ #
        model.train()
        running_loss = 0.0
        all_labels_train = []
        all_preds_train = []

        for inputs, labels in train_loader:
            inputs = embedding_propagation(inputs, alpha) # calculate embeddings for inputs
            inputs, labels = inputs.view(inputs.size(0), -1).to(device), labels.to(device) # load inputs & labels onto gpu
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels) # criterion is loss fct passed to function, NaN values are masked there
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            # Store predictions & labels for AUC-PR computation
            all_labels_train.append(labels.detach().cpu().numpy())
            all_preds_train.append(torch.sigmoid(outputs).detach().cpu().numpy())  # Convert logits to probabilities

        # Compute training AUC-PR
        train_pr_auc, train_roc_auc, _, _ = getPrAucIndividualClass("Train", all_labels_train, all_preds_train, writer, epoch)
        epoch_loss_train = running_loss / len(train_loader)

        # log loss and auc-pr to tensorboard
        # writer.add_scalar("Loss/Training", epoch_loss_train, epoch)

        # --------- EVALUATION AFTER EPOCH --------------- #
        model.eval()
        val_loss = 0.0
        all_labels_val = []
        all_preds_val = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = embedding_propagation(inputs, alpha) # compute embeddings for inputs
                inputs, labels = inputs.to(device), labels.to(device) # load to gpu

                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                # Store predictions & labels for AUC-PR computation
                all_labels_val.append(labels.cpu().numpy())
                all_preds_val.append(torch.sigmoid(outputs).cpu().numpy())  # Convert logits to probabilities

        epoch_loss_val = val_loss / len(val_loader)

        # writer.add_scalar("Loss/Validation", epoch_loss_val, epoch) # tensorboard
        # Compute Validation metrics
        val_pr_auc, val_roc_auc, _, _ = getPrAucIndividualClass("Val", all_labels_val, all_preds_val, writer, epoch)
        # if better, store model
        saved = save_best_model(model, avg_pr_auc=val_pr_auc, best_score=best_score, file_path=file_path)
        if saved:
            best_score = val_pr_auc
        # ------------------- END of EPOCH STUFF ------------- #
        print(f"Epoch {epoch+1}/{num_epochs} | "
              f"Train Loss: {epoch_loss_train:.4f}, Avg Train AUC-PR: {train_pr_auc:.4f}, Avg Train AUC-ROC: {train_roc_auc:.4f} | "
              f"Val Loss: {epoch_loss_val:.4f}, Avg Val AUC-PR: {val_pr_auc:.4f}, Avg Val AUC-ROC: {val_roc_auc:.4f}"
        )
        
        # # Log model parameters and gradients to tensorboard
        # for name, param in model.named_parameters():
        #     writer.add_histogram(name, param, epoch)
        #     writer.add_histogram(f"{name}.grad", param.grad, epoch)
        # # log model architecture
        # writer.add_graph(model, torch.randn(1, 2248).to(device))
    
    # ----------- EVALUATE BEST MODEL ------------- #
    model.load_state_dict(torch.load(file_path, map_location=device)) # load best model
    model.eval()
    val_loss = 0.0
    all_labels_val = []
    all_preds_val = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs = embedding_propagation(inputs, alpha) # compute embeddings for inputs
            inputs, labels = inputs.to(device), labels.to(device) # load input & labels onto gpu

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            # Store predictions & labels for AUC-PR computation
            all_labels_val.append(labels.cpu().numpy())
            all_preds_val.append(torch.sigmoid(outputs).cpu().numpy())  # Convert logits to probabilities

    epoch_loss_val = val_loss / len(val_loader)
    # writer.add_scalar("Loss/Validation", epoch_loss_val, epoch) # tensorboard

    # Compute metrics for best model and return them
    val_pr_auc, val_roc_auc, val_pr_auc_per_task, val_roc_auc_per_task = getPrAucIndividualClass("Best Val", all_labels_val, all_preds_val, writer, epoch)
    print(f"Best Model Results | "
              f"Avg Val AUC-PR: {val_pr_auc:.4f}, Avg Val AUC-ROC: {val_roc_auc:.4f}"
              
        )
    return epoch_loss_val, val_pr_auc, val_roc_auc, val_pr_auc_per_task, val_roc_auc_per_task

# %%
# creae dataloaders
def get_datasets(X_train, y_train, X_val, y_val, X_test, y_test, seed):
    def worker_init_fn(worker_id):
        # Adjust the seed based on the worker id to ensure different seeds for each worker.
        np.random.seed(seed + worker_id)
        random.seed(seed + worker_id)

    batch_size = 120
    train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,worker_init_fn=worker_init_fn)

    val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True,worker_init_fn=worker_init_fn)

    test_dataset = TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32))
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=worker_init_fn)

    return train_loader, val_loader, test_loader

# %%
input_size = 2248 
hidden_sizes = [120, 48, None]
output_size = 9
alpha = 0.35
lr = 0.001
dropout_rates = [0.3, 0.5] # input dropout, hidden dropout
seeds = [8479, 227, 5413, 8179, 7528]

# list to collect results avg over task
avg_results = {
        "Delta-AUC-PR": [],
        "ROC-AUC": []
    }

# list to collect results per task
all_results = {
        "Delta-AUC-PR": [],
        "ROC-AUC": []
    } 

# train and evaluate model 5 times
for run in range(5):
    # set seed
    seed_value = seeds[run]
    torch.manual_seed(seed_value)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
    np.random.seed(seed_value)
    random.seed(seed_value)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)

    # initialize
    # writer = SummaryWriter(f"manual_runs/run_35_upsampling") # tensorboard
    writer = None
    model = NeuralNetwork(input_size, hidden_sizes, output_size, dropout_rates)
    criterion = masked_bce_loss
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # train model
    train_loader, val_loader, test_loader = get_datasets(X_train, y_train, X_val, y_val, X_test, y_test, seed_value)
    val_loss, val_delta_auc_pr, val_roc_auc, val_pr_auc_per_task, val_roc_auc_per_task = train_model(model, train_loader, test_loader, criterion, optimizer, device, writer, num_epochs=20)
    
    # collect results
    avg_results["Delta-AUC-PR"].append(val_delta_auc_pr)
    avg_results["ROC-AUC"].append(val_roc_auc)

    all_results["Delta-AUC-PR"].append(np.array(val_pr_auc_per_task))
    all_results["ROC-AUC"].append(np.array(val_roc_auc_per_task))
    
    # ------- for hyperparameter tuning ------- #
    # val_loss, val_delta_auc_pr, val_roc_auc = train_model(model, train_loader, val_loader, criterion, optimizer, device, writer, num_epochs=20)

    # hparams = {
    #     "lr": lr,
    #     "batch_size": batch_size,
    #     "optimizer": "Adam",
    #     "hidden_sizes_1": hidden_sizes[0],
    #     "hidden_sizes_2": hidden_sizes[1]
    # }
    # metrics = {
    #     "auc-pr": val_delta_auc_pr,
    #     "loss": val_loss
    # }
    # writer.add_hparams(hparams, metrics)
    # writer.close()
# Out:
# cuda
# Saved new best model with avg PR AUC: 0.0838
# Epoch 1/20 | Train Loss: 0.0498, Avg Train AUC-PR: 0.0012, Avg Train AUC-ROC: 0.5888 | Val Loss: 0.0213, Avg Val AUC-PR: 0.0838, Avg Val AUC-ROC: 0.7259
# Current avg PR AUC: 0.0308 did not improve over best score: 0.0838
# Epoch 2/20 | Train Loss: 0.0156, Avg Train AUC-PR: 0.0072, Avg Train AUC-ROC: 0.6775 | Val Loss: 0.0213, Avg Val AUC-PR: 0.0308, Avg Val AUC-ROC: 0.7156
# Current avg PR AUC: 0.0495 did not improve over best score: 0.0838
# Epoch 3/20 | Train Loss: 0.0137, Avg Train AUC-PR: 0.0127, Avg Train AUC-ROC: 0.7816 | Val Loss: 0.0217, Avg Val AUC-PR: 0.0495, Avg Val AUC-ROC: 0.7280
# Current avg PR AUC: 0.0292 did not improve over best score: 0.0838
# Epoch 4/20 | Train Loss: 0.0128, Avg Train AUC-PR: 0.0235, Avg Train AUC-ROC: 0.8252 | Val Loss: 0.0220, Avg Val AUC-PR: 0.0292, Avg Val AUC-ROC: 0.6904
# Current avg PR AUC: 0.0266 did not improve over best score: 0.0838
# Epoch 5/20 | Train Loss: 0.0117, Avg Train AUC-PR: 0.0322, Avg Train AUC-ROC: 0.8730 | Val Loss: 0.0255, Avg Val AUC-PR: 0.0266, Avg Val AUC-ROC: 0.6944
# Current avg PR AUC: 0.0155 did not improve over best score: 0.0838
# Epoch 6/20 | Train Loss: 0.0098, Avg Train AUC-PR: 0.1660, Avg Train AUC-ROC: 0.9313 | Val Loss: 0.0254, Avg Val AUC-PR: 0.0155, Avg Val AUC-ROC: 0.7135
# Current avg PR AUC: 0.0312 did not improve over best score: 0.0838
# Epoch 7/20 | Train Loss: 0.0095, Avg Train AUC-PR: 0.1157, Avg Train AUC-ROC: 0.9441 | Val Loss: 0.0299, Avg Val AUC-PR: 0.0312, Avg Val AUC-ROC: 0.6611
# Current avg PR AUC: 0.0274 did not improve over best score: 0.0838
# Epoch 8/20 | Train Loss: 0.0092, Avg Train AUC-PR: 0.1510, Avg Train AUC-ROC: 0.9520 | Val Loss: 0.0300, Avg Val AUC-PR: 0.0274, Avg Val AUC-ROC: 0.6796
# Saved new best model with avg PR AUC: 0.1178
# Epoch 9/20 | Train Loss: 0.0077, Avg Train AUC-PR: 0.2679, Avg Train AUC-ROC: 0.9694 | Val Loss: 0.0310, Avg Val AUC-PR: 0.1178, Avg Val AUC-ROC: 0.7132
# Saved new best model with avg PR AUC: 0.1772
# Epoch 10/20 | Train Loss: 0.0064, Avg Train AUC-PR: 0.4176, Avg Train AUC-ROC: 0.9808 | Val Loss: 0.0332, Avg Val AUC-PR: 0.1772, Avg Val AUC-ROC: 0.6655
# Current avg PR AUC: 0.0562 did not improve over best score: 0.1772
# Epoch 11/20 | Train Loss: 0.0061, Avg Train AUC-PR: 0.4061, Avg Train AUC-ROC: 0.9878 | Val Loss: 0.0404, Avg Val AUC-PR: 0.0562, Avg Val AUC-ROC: 0.6944
# Saved new best model with avg PR AUC: 0.2366
# Epoch 12/20 | Train Loss: 0.0062, Avg Train AUC-PR: 0.4339, Avg Train AUC-ROC: 0.9819 | Val Loss: 0.0357, Avg Val AUC-PR: 0.2366, Avg Val AUC-ROC: 0.6795
# Current avg PR AUC: 0.1393 did not improve over best score: 0.2366
# Epoch 13/20 | Train Loss: 0.0062, Avg Train AUC-PR: 0.4680, Avg Train AUC-ROC: 0.9846 | Val Loss: 0.0405, Avg Val AUC-PR: 0.1393, Avg Val AUC-ROC: 0.6718
# Current avg PR AUC: 0.1936 did not improve over best score: 0.2366
# Epoch 14/20 | Train Loss: 0.0054, Avg Train AUC-PR: 0.5212, Avg Train AUC-ROC: 0.9907 | Val Loss: 0.0381, Avg Val AUC-PR: 0.1936, Avg Val AUC-ROC: 0.6772
# Current avg PR AUC: 0.1013 did not improve over best score: 0.2366
# Epoch 15/20 | Train Loss: 0.0049, Avg Train AUC-PR: 0.5678, Avg Train AUC-ROC: 0.9923 | Val Loss: 0.0448, Avg Val AUC-PR: 0.1013, Avg Val AUC-ROC: 0.6417
# Current avg PR AUC: 0.2217 did not improve over best score: 0.2366
# Epoch 16/20 | Train Loss: 0.0047, Avg Train AUC-PR: 0.6119, Avg Train AUC-ROC: 0.9881 | Val Loss: 0.0422, Avg Val AUC-PR: 0.2217, Avg Val AUC-ROC: 0.6605
# Current avg PR AUC: 0.1301 did not improve over best score: 0.2366
# Epoch 17/20 | Train Loss: 0.0049, Avg Train AUC-PR: 0.5901, Avg Train AUC-ROC: 0.9925 | Val Loss: 0.0452, Avg Val AUC-PR: 0.1301, Avg Val AUC-ROC: 0.6708
# Current avg PR AUC: 0.0213 did not improve over best score: 0.2366
# Epoch 18/20 | Train Loss: 0.0055, Avg Train AUC-PR: 0.5352, Avg Train AUC-ROC: 0.9896 | Val Loss: 0.0525, Avg Val AUC-PR: 0.0213, Avg Val AUC-ROC: 0.6427
# Current avg PR AUC: 0.0097 did not improve over best score: 0.2366
# Epoch 19/20 | Train Loss: 0.0042, Avg Train AUC-PR: 0.6878, Avg Train AUC-ROC: 0.9926 | Val Loss: 0.0484, Avg Val AUC-PR: 0.0097, Avg Val AUC-ROC: 0.6513
# Current avg PR AUC: 0.0332 did not improve over best score: 0.2366
# Epoch 20/20 | Train Loss: 0.0045, Avg Train AUC-PR: 0.6565, Avg Train AUC-ROC: 0.9937 | Val Loss: 0.0530, Avg Val AUC-PR: 0.0332, Avg Val AUC-ROC: 0.6337
# Best Model Results | Avg Val AUC-PR: 0.1473, Avg Val AUC-ROC: 0.6806
# cuda
# Saved new best model with avg PR AUC: 0.0521
# Epoch 1/20 | Train Loss: 0.0507, Avg Train AUC-PR: 0.0013, Avg Train AUC-ROC: 0.5730 | Val Loss: 0.0213, Avg Val AUC-PR: 0.0521, Avg Val AUC-ROC: 0.6732
# Current avg PR AUC: 0.0082 did not improve over best score: 0.0521
# Epoch 2/20 | Train Loss: 0.0142, Avg Train AUC-PR: 0.0069, Avg Train AUC-ROC: 0.7303 | Val Loss: 0.0221, Avg Val AUC-PR: 0.0082, Avg Val AUC-ROC: 0.6638
# Saved new best model with avg PR AUC: 0.0562
# Epoch 3/20 | Train Loss: 0.0135, Avg Train AUC-PR: 0.0152, Avg Train AUC-ROC: 0.7709 | Val Loss: 0.0223, Avg Val AUC-PR: 0.0562, Avg Val AUC-ROC: 0.6864
# Current avg PR AUC: 0.0381 did not improve over best score: 0.0562
# Epoch 4/20 | Train Loss: 0.0117, Avg Train AUC-PR: 0.0214, Avg Train AUC-ROC: 0.8757 | Val Loss: 0.0220, Avg Val AUC-PR: 0.0381, Avg Val AUC-ROC: 0.6869
# Saved new best model with avg PR AUC: 0.0825
# Epoch 5/20 | Train Loss: 0.0116, Avg Train AUC-PR: 0.0533, Avg Train AUC-ROC: 0.8727 | Val Loss: 0.0227, Avg Val AUC-PR: 0.0825, Avg Val AUC-ROC: 0.7355
# Current avg PR AUC: 0.0712 did not improve over best score: 0.0825
# Epoch 6/20 | Train Loss: 0.0103, Avg Train AUC-PR: 0.1031, Avg Train AUC-ROC: 0.9100 | Val Loss: 0.0243, Avg Val AUC-PR: 0.0712, Avg Val AUC-ROC: 0.7007
# Current avg PR AUC: 0.0594 did not improve over best score: 0.0825
# Epoch 7/20 | Train Loss: 0.0088, Avg Train AUC-PR: 0.1452, Avg Train AUC-ROC: 0.9617 | Val Loss: 0.0241, Avg Val AUC-PR: 0.0594, Avg Val AUC-ROC: 0.6963
# Current avg PR AUC: 0.0602 did not improve over best score: 0.0825
# Epoch 8/20 | Train Loss: 0.0090, Avg Train AUC-PR: 0.1945, Avg Train AUC-ROC: 0.9457 | Val Loss: 0.0296, Avg Val AUC-PR: 0.0602, Avg Val AUC-ROC: 0.6540
# Saved new best model with avg PR AUC: 0.0916
# Epoch 9/20 | Train Loss: 0.0075, Avg Train AUC-PR: 0.3030, Avg Train AUC-ROC: 0.9716 | Val Loss: 0.0327, Avg Val AUC-PR: 0.0916, Avg Val AUC-ROC: 0.7097
# Saved new best model with avg PR AUC: 0.1007
# Epoch 10/20 | Train Loss: 0.0067, Avg Train AUC-PR: 0.3268, Avg Train AUC-ROC: 0.9802 | Val Loss: 0.0333, Avg Val AUC-PR: 0.1007, Avg Val AUC-ROC: 0.6555
# Current avg PR AUC: 0.0700 did not improve over best score: 0.1007
# Epoch 11/20 | Train Loss: 0.0063, Avg Train AUC-PR: 0.3841, Avg Train AUC-ROC: 0.9856 | Val Loss: 0.0376, Avg Val AUC-PR: 0.0700, Avg Val AUC-ROC: 0.6643
# Current avg PR AUC: 0.0635 did not improve over best score: 0.1007
# Epoch 12/20 | Train Loss: 0.0052, Avg Train AUC-PR: 0.5233, Avg Train AUC-ROC: 0.9894 | Val Loss: 0.0361, Avg Val AUC-PR: 0.0635, Avg Val AUC-ROC: 0.6572
# Saved new best model with avg PR AUC: 0.1261
# Epoch 13/20 | Train Loss: 0.0056, Avg Train AUC-PR: 0.5016, Avg Train AUC-ROC: 0.9901 | Val Loss: 0.0390, Avg Val AUC-PR: 0.1261, Avg Val AUC-ROC: 0.6490
# Current avg PR AUC: 0.0717 did not improve over best score: 0.1261
# Epoch 14/20 | Train Loss: 0.0052, Avg Train AUC-PR: 0.5649, Avg Train AUC-ROC: 0.9920 | Val Loss: 0.0447, Avg Val AUC-PR: 0.0717, Avg Val AUC-ROC: 0.6684
# Saved new best model with avg PR AUC: 0.1591
# Epoch 15/20 | Train Loss: 0.0051, Avg Train AUC-PR: 0.5499, Avg Train AUC-ROC: 0.9914 | Val Loss: 0.0416, Avg Val AUC-PR: 0.1591, Avg Val AUC-ROC: 0.6729
# Saved new best model with avg PR AUC: 0.1982
# Epoch 16/20 | Train Loss: 0.0049, Avg Train AUC-PR: 0.5957, Avg Train AUC-ROC: 0.9894 | Val Loss: 0.0381, Avg Val AUC-PR: 0.1982, Avg Val AUC-ROC: 0.7242
# Saved new best model with avg PR AUC: 0.2157
# Epoch 17/20 | Train Loss: 0.0048, Avg Train AUC-PR: 0.6066, Avg Train AUC-ROC: 0.9922 | Val Loss: 0.0408, Avg Val AUC-PR: 0.2157, Avg Val AUC-ROC: 0.7199
# Current avg PR AUC: 0.1559 did not improve over best score: 0.2157
# Epoch 18/20 | Train Loss: 0.0041, Avg Train AUC-PR: 0.6411, Avg Train AUC-ROC: 0.9954 | Val Loss: 0.0461, Avg Val AUC-PR: 0.1559, Avg Val AUC-ROC: 0.6701
# Current avg PR AUC: 0.1307 did not improve over best score: 0.2157
# Epoch 19/20 | Train Loss: 0.0048, Avg Train AUC-PR: 0.6096, Avg Train AUC-ROC: 0.9930 | Val Loss: 0.0435, Avg Val AUC-PR: 0.1307, Avg Val AUC-ROC: 0.6710
# Current avg PR AUC: 0.1936 did not improve over best score: 0.2157
# Epoch 20/20 | Train Loss: 0.0048, Avg Train AUC-PR: 0.6035, Avg Train AUC-ROC: 0.9908 | Val Loss: 0.0471, Avg Val AUC-PR: 0.1936, Avg Val AUC-ROC: 0.6473
# Best Model Results | Avg Val AUC-PR: 0.1935, Avg Val AUC-ROC: 0.6788
# cuda
# Saved new best model with avg PR AUC: 0.0058
# Epoch 1/20 | Train Loss: 0.0554, Avg Train AUC-PR: 0.0076, Avg Train AUC-ROC: 0.5803 | Val Loss: 0.0234, Avg Val AUC-PR: 0.0058, Avg Val AUC-ROC: 0.6525
# Saved new best model with avg PR AUC: 0.0422
# Epoch 2/20 | Train Loss: 0.0141, Avg Train AUC-PR: 0.0092, Avg Train AUC-ROC: 0.7388 | Val Loss: 0.0232, Avg Val AUC-PR: 0.0422, Avg Val AUC-ROC: 0.6645
# Saved new best model with avg PR AUC: 0.0672
# Epoch 3/20 | Train Loss: 0.0130, Avg Train AUC-PR: 0.0137, Avg Train AUC-ROC: 0.8183 | Val Loss: 0.0227, Avg Val AUC-PR: 0.0672, Avg Val AUC-ROC: 0.6531
# Current avg PR AUC: 0.0167 did not improve over best score: 0.0672
# Epoch 4/20 | Train Loss: 0.0121, Avg Train AUC-PR: 0.0403, Avg Train AUC-ROC: 0.8556 | Val Loss: 0.0227, Avg Val AUC-PR: 0.0167, Avg Val AUC-ROC: 0.7081
# Current avg PR AUC: 0.0455 did not improve over best score: 0.0672
# Epoch 5/20 | Train Loss: 0.0117, Avg Train AUC-PR: 0.0645, Avg Train AUC-ROC: 0.8730 | Val Loss: 0.0257, Avg Val AUC-PR: 0.0455, Avg Val AUC-ROC: 0.7011
# Current avg PR AUC: 0.0624 did not improve over best score: 0.0672
# Epoch 6/20 | Train Loss: 0.0102, Avg Train AUC-PR: 0.0877, Avg Train AUC-ROC: 0.9202 | Val Loss: 0.0247, Avg Val AUC-PR: 0.0624, Avg Val AUC-ROC: 0.7077
# Current avg PR AUC: 0.0109 did not improve over best score: 0.0672
# Epoch 7/20 | Train Loss: 0.0089, Avg Train AUC-PR: 0.1323, Avg Train AUC-ROC: 0.9549 | Val Loss: 0.0284, Avg Val AUC-PR: 0.0109, Avg Val AUC-ROC: 0.6627
# Current avg PR AUC: 0.0480 did not improve over best score: 0.0672
# Epoch 8/20 | Train Loss: 0.0082, Avg Train AUC-PR: 0.2160, Avg Train AUC-ROC: 0.9601 | Val Loss: 0.0282, Avg Val AUC-PR: 0.0480, Avg Val AUC-ROC: 0.7091
# Current avg PR AUC: 0.0336 did not improve over best score: 0.0672
# Epoch 9/20 | Train Loss: 0.0077, Avg Train AUC-PR: 0.2567, Avg Train AUC-ROC: 0.9718 | Val Loss: 0.0314, Avg Val AUC-PR: 0.0336, Avg Val AUC-ROC: 0.7238
# Current avg PR AUC: 0.0566 did not improve over best score: 0.0672
# Epoch 10/20 | Train Loss: 0.0062, Avg Train AUC-PR: 0.3682, Avg Train AUC-ROC: 0.9869 | Val Loss: 0.0351, Avg Val AUC-PR: 0.0566, Avg Val AUC-ROC: 0.6893
# Saved new best model with avg PR AUC: 0.0974
# Epoch 11/20 | Train Loss: 0.0063, Avg Train AUC-PR: 0.4352, Avg Train AUC-ROC: 0.9816 | Val Loss: 0.0341, Avg Val AUC-PR: 0.0974, Avg Val AUC-ROC: 0.6935
# Current avg PR AUC: 0.0594 did not improve over best score: 0.0974
# Epoch 12/20 | Train Loss: 0.0062, Avg Train AUC-PR: 0.4183, Avg Train AUC-ROC: 0.9839 | Val Loss: 0.0384, Avg Val AUC-PR: 0.0594, Avg Val AUC-ROC: 0.6676
# Current avg PR AUC: 0.0473 did not improve over best score: 0.0974
# Epoch 13/20 | Train Loss: 0.0056, Avg Train AUC-PR: 0.4826, Avg Train AUC-ROC: 0.9895 | Val Loss: 0.0383, Avg Val AUC-PR: 0.0473, Avg Val AUC-ROC: 0.6809
# Current avg PR AUC: 0.0495 did not improve over best score: 0.0974
# Epoch 14/20 | Train Loss: 0.0057, Avg Train AUC-PR: 0.4818, Avg Train AUC-ROC: 0.9899 | Val Loss: 0.0372, Avg Val AUC-PR: 0.0495, Avg Val AUC-ROC: 0.6920
# Saved new best model with avg PR AUC: 0.1661
# Epoch 15/20 | Train Loss: 0.0050, Avg Train AUC-PR: 0.5383, Avg Train AUC-ROC: 0.9923 | Val Loss: 0.0449, Avg Val AUC-PR: 0.1661, Avg Val AUC-ROC: 0.6677
# Current avg PR AUC: 0.0468 did not improve over best score: 0.1661
# Epoch 16/20 | Train Loss: 0.0049, Avg Train AUC-PR: 0.5985, Avg Train AUC-ROC: 0.9919 | Val Loss: 0.0453, Avg Val AUC-PR: 0.0468, Avg Val AUC-ROC: 0.6571
# Current avg PR AUC: 0.0501 did not improve over best score: 0.1661
# Epoch 17/20 | Train Loss: 0.0054, Avg Train AUC-PR: 0.5415, Avg Train AUC-ROC: 0.9865 | Val Loss: 0.0454, Avg Val AUC-PR: 0.0501, Avg Val AUC-ROC: 0.6815
# Current avg PR AUC: 0.0335 did not improve over best score: 0.1661
# Epoch 18/20 | Train Loss: 0.0052, Avg Train AUC-PR: 0.5554, Avg Train AUC-ROC: 0.9917 | Val Loss: 0.0500, Avg Val AUC-PR: 0.0335, Avg Val AUC-ROC: 0.6523
# Current avg PR AUC: 0.0540 did not improve over best score: 0.1661
# Epoch 19/20 | Train Loss: 0.0046, Avg Train AUC-PR: 0.5946, Avg Train AUC-ROC: 0.9956 | Val Loss: 0.0475, Avg Val AUC-PR: 0.0540, Avg Val AUC-ROC: 0.6414
# Current avg PR AUC: 0.0502 did not improve over best score: 0.1661
# Epoch 20/20 | Train Loss: 0.0040, Avg Train AUC-PR: 0.6942, Avg Train AUC-ROC: 0.9955 | Val Loss: 0.0519, Avg Val AUC-PR: 0.0502, Avg Val AUC-ROC: 0.6505
# Best Model Results | Avg Val AUC-PR: 0.0648, Avg Val AUC-ROC: 0.6627
# cuda
# Saved new best model with avg PR AUC: 0.0271
# Epoch 1/20 | Train Loss: 0.0573, Avg Train AUC-PR: 0.0005, Avg Train AUC-ROC: 0.5245 | Val Loss: 0.0204, Avg Val AUC-PR: 0.0271, Avg Val AUC-ROC: 0.7373
# Current avg PR AUC: 0.0162 did not improve over best score: 0.0271
# Epoch 2/20 | Train Loss: 0.0139, Avg Train AUC-PR: 0.0076, Avg Train AUC-ROC: 0.7456 | Val Loss: 0.0217, Avg Val AUC-PR: 0.0162, Avg Val AUC-ROC: 0.7082
# Saved new best model with avg PR AUC: 0.0305
# Epoch 3/20 | Train Loss: 0.0137, Avg Train AUC-PR: 0.0250, Avg Train AUC-ROC: 0.7769 | Val Loss: 0.0214, Avg Val AUC-PR: 0.0305, Avg Val AUC-ROC: 0.7623
# Saved new best model with avg PR AUC: 0.0481
# Epoch 4/20 | Train Loss: 0.0123, Avg Train AUC-PR: 0.0178, Avg Train AUC-ROC: 0.8553 | Val Loss: 0.0216, Avg Val AUC-PR: 0.0481, Avg Val AUC-ROC: 0.7475
# Saved new best model with avg PR AUC: 0.0547
# Epoch 5/20 | Train Loss: 0.0117, Avg Train AUC-PR: 0.0509, Avg Train AUC-ROC: 0.8755 | Val Loss: 0.0243, Avg Val AUC-PR: 0.0547, Avg Val AUC-ROC: 0.7286
# Saved new best model with avg PR AUC: 0.0588
# Epoch 6/20 | Train Loss: 0.0107, Avg Train AUC-PR: 0.0761, Avg Train AUC-ROC: 0.9169 | Val Loss: 0.0213, Avg Val AUC-PR: 0.0588, Avg Val AUC-ROC: 0.7362
# Current avg PR AUC: 0.0508 did not improve over best score: 0.0588
# Epoch 7/20 | Train Loss: 0.0094, Avg Train AUC-PR: 0.1489, Avg Train AUC-ROC: 0.9419 | Val Loss: 0.0254, Avg Val AUC-PR: 0.0508, Avg Val AUC-ROC: 0.7281
# Saved new best model with avg PR AUC: 0.1423
# Epoch 8/20 | Train Loss: 0.0090, Avg Train AUC-PR: 0.1457, Avg Train AUC-ROC: 0.9495 | Val Loss: 0.0264, Avg Val AUC-PR: 0.1423, Avg Val AUC-ROC: 0.7003
# Current avg PR AUC: 0.0750 did not improve over best score: 0.1423
# Epoch 9/20 | Train Loss: 0.0082, Avg Train AUC-PR: 0.2508, Avg Train AUC-ROC: 0.9599 | Val Loss: 0.0272, Avg Val AUC-PR: 0.0750, Avg Val AUC-ROC: 0.7199
# Current avg PR AUC: 0.0765 did not improve over best score: 0.1423
# Epoch 10/20 | Train Loss: 0.0073, Avg Train AUC-PR: 0.2904, Avg Train AUC-ROC: 0.9696 | Val Loss: 0.0302, Avg Val AUC-PR: 0.0765, Avg Val AUC-ROC: 0.7089
# Current avg PR AUC: 0.0260 did not improve over best score: 0.1423
# Epoch 11/20 | Train Loss: 0.0069, Avg Train AUC-PR: 0.4002, Avg Train AUC-ROC: 0.9710 | Val Loss: 0.0319, Avg Val AUC-PR: 0.0260, Avg Val AUC-ROC: 0.6919
# Current avg PR AUC: 0.0280 did not improve over best score: 0.1423
# Epoch 12/20 | Train Loss: 0.0062, Avg Train AUC-PR: 0.4369, Avg Train AUC-ROC: 0.9817 | Val Loss: 0.0363, Avg Val AUC-PR: 0.0280, Avg Val AUC-ROC: 0.7301
# Current avg PR AUC: 0.0216 did not improve over best score: 0.1423
# Epoch 13/20 | Train Loss: 0.0060, Avg Train AUC-PR: 0.4550, Avg Train AUC-ROC: 0.9834 | Val Loss: 0.0346, Avg Val AUC-PR: 0.0216, Avg Val AUC-ROC: 0.6935
# Current avg PR AUC: 0.0454 did not improve over best score: 0.1423
# Epoch 14/20 | Train Loss: 0.0056, Avg Train AUC-PR: 0.5140, Avg Train AUC-ROC: 0.9891 | Val Loss: 0.0388, Avg Val AUC-PR: 0.0454, Avg Val AUC-ROC: 0.6946
# Current avg PR AUC: 0.0378 did not improve over best score: 0.1423
# Epoch 15/20 | Train Loss: 0.0063, Avg Train AUC-PR: 0.4602, Avg Train AUC-ROC: 0.9838 | Val Loss: 0.0397, Avg Val AUC-PR: 0.0378, Avg Val AUC-ROC: 0.6991
# Current avg PR AUC: 0.0576 did not improve over best score: 0.1423
# Epoch 16/20 | Train Loss: 0.0047, Avg Train AUC-PR: 0.5843, Avg Train AUC-ROC: 0.9922 | Val Loss: 0.0443, Avg Val AUC-PR: 0.0576, Avg Val AUC-ROC: 0.6800
# Current avg PR AUC: 0.0489 did not improve over best score: 0.1423
# Epoch 17/20 | Train Loss: 0.0044, Avg Train AUC-PR: 0.6368, Avg Train AUC-ROC: 0.9931 | Val Loss: 0.0442, Avg Val AUC-PR: 0.0489, Avg Val AUC-ROC: 0.6992
# Current avg PR AUC: 0.0508 did not improve over best score: 0.1423
# Epoch 18/20 | Train Loss: 0.0050, Avg Train AUC-PR: 0.5319, Avg Train AUC-ROC: 0.9933 | Val Loss: 0.0466, Avg Val AUC-PR: 0.0508, Avg Val AUC-ROC: 0.6414
# Current avg PR AUC: 0.0275 did not improve over best score: 0.1423
# Epoch 19/20 | Train Loss: 0.0048, Avg Train AUC-PR: 0.5955, Avg Train AUC-ROC: 0.9930 | Val Loss: 0.0482, Avg Val AUC-PR: 0.0275, Avg Val AUC-ROC: 0.6391
# Current avg PR AUC: 0.0477 did not improve over best score: 0.1423
# Epoch 20/20 | Train Loss: 0.0040, Avg Train AUC-PR: 0.7281, Avg Train AUC-ROC: 0.9909 | Val Loss: 0.0521, Avg Val AUC-PR: 0.0477, Avg Val AUC-ROC: 0.6402
# Best Model Results | Avg Val AUC-PR: 0.1003, Avg Val AUC-ROC: 0.7423
# cuda
# Saved new best model with avg PR AUC: 0.0110
# Epoch 1/20 | Train Loss: 0.0487, Avg Train AUC-PR: 0.0011, Avg Train AUC-ROC: 0.5620 | Val Loss: 0.0222, Avg Val AUC-PR: 0.0110, Avg Val AUC-ROC: 0.6744
# Saved new best model with avg PR AUC: 0.0482
# Epoch 2/20 | Train Loss: 0.0141, Avg Train AUC-PR: 0.0081, Avg Train AUC-ROC: 0.7449 | Val Loss: 0.0210, Avg Val AUC-PR: 0.0482, Avg Val AUC-ROC: 0.7102
# Current avg PR AUC: 0.0116 did not improve over best score: 0.0482
# Epoch 3/20 | Train Loss: 0.0130, Avg Train AUC-PR: 0.0286, Avg Train AUC-ROC: 0.8107 | Val Loss: 0.0216, Avg Val AUC-PR: 0.0116, Avg Val AUC-ROC: 0.7309
# Current avg PR AUC: 0.0381 did not improve over best score: 0.0482
# Epoch 4/20 | Train Loss: 0.0122, Avg Train AUC-PR: 0.0383, Avg Train AUC-ROC: 0.8561 | Val Loss: 0.0230, Avg Val AUC-PR: 0.0381, Avg Val AUC-ROC: 0.6922
# Current avg PR AUC: 0.0189 did not improve over best score: 0.0482
# Epoch 5/20 | Train Loss: 0.0122, Avg Train AUC-PR: 0.0460, Avg Train AUC-ROC: 0.8667 | Val Loss: 0.0218, Avg Val AUC-PR: 0.0189, Avg Val AUC-ROC: 0.7324
# Saved new best model with avg PR AUC: 0.0617
# Epoch 6/20 | Train Loss: 0.0103, Avg Train AUC-PR: 0.0840, Avg Train AUC-ROC: 0.9184 | Val Loss: 0.0251, Avg Val AUC-PR: 0.0617, Avg Val AUC-ROC: 0.7377
# Saved new best model with avg PR AUC: 0.0663
# Epoch 7/20 | Train Loss: 0.0090, Avg Train AUC-PR: 0.1722, Avg Train AUC-ROC: 0.9477 | Val Loss: 0.0262, Avg Val AUC-PR: 0.0663, Avg Val AUC-ROC: 0.7274
# Saved new best model with avg PR AUC: 0.0900
# Epoch 8/20 | Train Loss: 0.0080, Avg Train AUC-PR: 0.2257, Avg Train AUC-ROC: 0.9655 | Val Loss: 0.0278, Avg Val AUC-PR: 0.0900, Avg Val AUC-ROC: 0.7339
# Saved new best model with avg PR AUC: 0.1880
# Epoch 9/20 | Train Loss: 0.0076, Avg Train AUC-PR: 0.2771, Avg Train AUC-ROC: 0.9762 | Val Loss: 0.0282, Avg Val AUC-PR: 0.1880, Avg Val AUC-ROC: 0.7544
# Current avg PR AUC: 0.0728 did not improve over best score: 0.1880
# Epoch 10/20 | Train Loss: 0.0076, Avg Train AUC-PR: 0.3106, Avg Train AUC-ROC: 0.9674 | Val Loss: 0.0317, Avg Val AUC-PR: 0.0728, Avg Val AUC-ROC: 0.7102
# Current avg PR AUC: 0.1576 did not improve over best score: 0.1880
# Epoch 11/20 | Train Loss: 0.0067, Avg Train AUC-PR: 0.4319, Avg Train AUC-ROC: 0.9727 | Val Loss: 0.0322, Avg Val AUC-PR: 0.1576, Avg Val AUC-ROC: 0.7267
# Current avg PR AUC: 0.0602 did not improve over best score: 0.1880
# Epoch 12/20 | Train Loss: 0.0062, Avg Train AUC-PR: 0.4263, Avg Train AUC-ROC: 0.9845 | Val Loss: 0.0318, Avg Val AUC-PR: 0.0602, Avg Val AUC-ROC: 0.7720
# Current avg PR AUC: 0.1357 did not improve over best score: 0.1880
# Epoch 13/20 | Train Loss: 0.0053, Avg Train AUC-PR: 0.5338, Avg Train AUC-ROC: 0.9878 | Val Loss: 0.0360, Avg Val AUC-PR: 0.1357, Avg Val AUC-ROC: 0.7252
# Current avg PR AUC: 0.1507 did not improve over best score: 0.1880
# Epoch 14/20 | Train Loss: 0.0053, Avg Train AUC-PR: 0.4988, Avg Train AUC-ROC: 0.9937 | Val Loss: 0.0374, Avg Val AUC-PR: 0.1507, Avg Val AUC-ROC: 0.7397
# Current avg PR AUC: 0.1638 did not improve over best score: 0.1880
# Epoch 15/20 | Train Loss: 0.0058, Avg Train AUC-PR: 0.5524, Avg Train AUC-ROC: 0.9825 | Val Loss: 0.0389, Avg Val AUC-PR: 0.1638, Avg Val AUC-ROC: 0.7126
# Current avg PR AUC: 0.0799 did not improve over best score: 0.1880
# Epoch 16/20 | Train Loss: 0.0055, Avg Train AUC-PR: 0.4959, Avg Train AUC-ROC: 0.9884 | Val Loss: 0.0373, Avg Val AUC-PR: 0.0799, Avg Val AUC-ROC: 0.7565
# Current avg PR AUC: 0.0784 did not improve over best score: 0.1880
# Epoch 17/20 | Train Loss: 0.0046, Avg Train AUC-PR: 0.5987, Avg Train AUC-ROC: 0.9938 | Val Loss: 0.0417, Avg Val AUC-PR: 0.0784, Avg Val AUC-ROC: 0.7399
# Current avg PR AUC: 0.1084 did not improve over best score: 0.1880
# Epoch 18/20 | Train Loss: 0.0048, Avg Train AUC-PR: 0.6186, Avg Train AUC-ROC: 0.9905 | Val Loss: 0.0509, Avg Val AUC-PR: 0.1084, Avg Val AUC-ROC: 0.6941
# Current avg PR AUC: 0.0574 did not improve over best score: 0.1880
# Epoch 19/20 | Train Loss: 0.0047, Avg Train AUC-PR: 0.6309, Avg Train AUC-ROC: 0.9916 | Val Loss: 0.0530, Avg Val AUC-PR: 0.0574, Avg Val AUC-ROC: 0.7289
# Current avg PR AUC: 0.0260 did not improve over best score: 0.1880
# Epoch 20/20 | Train Loss: 0.0050, Avg Train AUC-PR: 0.6004, Avg Train AUC-ROC: 0.9897 | Val Loss: 0.0484, Avg Val AUC-PR: 0.0260, Avg Val AUC-ROC: 0.7121
# Best Model Results | Avg Val AUC-PR: 0.0799, Avg Val AUC-ROC: 0.7606

# %%
# calculate mean and sd for five runs but don't average over tasks
final_auc_pr = np.mean(np.array(avg_results["Delta-AUC-PR"]))
final_roc_auc = np.mean(np.array(avg_results["ROC-AUC"]))
final_sd_auc_pr = np.std(np.array(avg_results["Delta-AUC-PR"]))
final_sd_roc_auc = np.std(np.array(avg_results["ROC-AUC"]))

# save in json convertible format
final_results = [{
    "Delta-AUC-PR": float(final_auc_pr),
    "ROC-AUC": float(final_roc_auc),
    "Sd-Delta-AUC-PR": float(final_sd_auc_pr),
    "Sd-ROC-AUC": float(final_sd_roc_auc)
}]
final_results

# write to json file
with open("./metrics/metrics_pretraining_ep.json", "w") as f:
    json.dump(final_results, f, indent=4)

# %%
all_results = {
    key: [arr.tolist() if isinstance(arr, np.ndarray) else arr for arr in value]
    for key, value in all_results.items()
}

# %%
# calculate mean and sd for five runs but don't average over tasks
avg_auc_pr_per_task = np.mean(np.array(all_results["Delta-AUC-PR"]), axis=0)
sd_auc_pr_per_task = np.std(np.array(all_results["Delta-AUC-PR"]), axis=0)

avg_roc_auc_per_task = np.mean(np.array(all_results["ROC-AUC"]), axis=0)
sd_roc_auc_per_task = np.std(np.array(all_results["ROC-AUC"]), axis=0)

# save in json convertible format
final_results_per_task = [{
    "Delta-AUC-PR per task": list(avg_auc_pr_per_task),
    "ROC-AUC per task": list(avg_roc_auc_per_task),
    "Sd-Delta-AUC-PR per task": list(sd_auc_pr_per_task),
    "Sd-ROC-AUC per task": list(sd_roc_auc_per_task)
}]
final_results_per_task

# write to json file
with open("./metrics/metrics_pretraining_ep_per_task.json", "w") as f:
    json.dump(final_results_per_task, f, indent=4)

# %%
# calculate mean and sd for five runs but do average over tasks
avg_auc_pr_per_run = np.mean(np.array(all_results["Delta-AUC-PR"]), axis=1)
sd_auc_pr_per_run = np.std(np.array(all_results["Delta-AUC-PR"]), axis=1)

avg_roc_auc_per_run = np.mean(np.array(all_results["ROC-AUC"]), axis=1)
sd_roc_auc_per_run = np.std(np.array(all_results["ROC-AUC"]), axis=1)

# save in json convertible format
final_results_per_run = [{
    "Delta-AUC-PR per run": list(avg_auc_pr_per_run),
    "ROC-AUC per run": list(avg_roc_auc_per_run),
    "Sd-Delta-AUC-PR per run": list(sd_auc_pr_per_run),
    "Sd-ROC-AUC per run": list(sd_roc_auc_per_run)
}]
final_results_per_run

# write to json file
with open("./metrics/metrics_pretraining_ep_per_run.json", "w") as f:
    json.dump(final_results_per_run, f, indent=4)
