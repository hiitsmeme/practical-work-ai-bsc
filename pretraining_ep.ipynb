# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,TensorDataset
import numpy as np
import random
import json
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import roc_auc_score, auc, precision_recall_curve

# %%
data = np.load('./data/data_scaled.npz')
X_train = data['X_train']
y_train = data['y_train']
X_val = data['X_val']
y_val = data["y_val"]
X_test = data['X_test']
y_test = data['y_test']

# %%
# function to calculate embeddings for model input
def embedding_propagation(X, alpha):
    # squared distances
    sq = torch.sum(X ** 2, dim=1, keepdim=True)  # shape: (num_samples, 1)
    distances_squared = sq + sq.t() - 2 * (X @ X.t())
    
    # adjacency matrix
    sigma2 = torch.var(distances_squared)
    A = torch.exp(-distances_squared / sigma2)
    A.fill_diagonal_(0)
    
    # diagonal matrix
    row_sums = torch.sum(A, dim=1)
    D12 = torch.diag(1 / torch.sqrt(row_sums))
    
    # laplacian matrix
    L = D12 @ A @ D12
    
    # propagator matrix
    num_samples = X.shape[0]
    I = torch.eye(num_samples, device=X.device, dtype=X.dtype)
    P = torch.inverse(I - alpha * L)
    
    # final embeddings
    X_final = P @ X
    
    return X_final

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size, dropout_rates=[0.5,0.25]):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_sizes[0])
        self.fc2 = nn.Linear(hidden_sizes[0], hidden_sizes[1])
        self.fc3 = nn.Linear(hidden_sizes[1], output_size)

        self.relu = nn.ReLU()
        self.input_dropout = nn.Dropout(dropout_rates[0])
        self.hidden_dropout = nn.Dropout(dropout_rates[1])

    def forward(self, x):
        x = self.input_dropout(x)
        x = self.relu(self.fc1(x))
        x = self.hidden_dropout(x)
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def getPrAucIndividualClass(train_or_val, all_labels, all_preds, writer, epoch):
    # stack label arrays vertically
    all_labels = np.vstack(all_labels)
    all_preds = np.vstack(all_preds)
    # convert them to torch, for gpu compatibility
    all_labels = torch.tensor(all_labels)
    all_preds = torch.tensor(all_preds)
    all_pr_auc = []
    all_roc_auc = []
    # loop over 9 tasks
    for class_idx in range(all_labels.shape[1]):
        mask = ~torch.isnan(all_labels[:, class_idx])   # mask out NaN values
        class_labels = all_labels[:,class_idx][mask]    # get labels for current class
        class_preds = all_preds[:,class_idx][mask]      # get model preds for current class
        baseline = class_labels.mean()      # baseline is portion of pos labels
        # calculate scores
        roc_auc = roc_auc_score(class_labels, class_preds)
        precision, recall, _ = precision_recall_curve(class_labels, class_preds)
        pr_auc = auc(recall, precision) - baseline
        # save scores
        all_pr_auc.append(pr_auc)
        all_roc_auc.append(roc_auc)

        # log to tensorboard
        # writer.add_pr_curve(f"{train_or_val} Precision-Recall Class {class_idx}", class_labels, class_preds, epoch)
        # writer.add_scalar(f"{train_or_val} PR-AUC Class {class_idx}", pr_auc, epoch)
        # writer.add_scalar(f"{train_or_val} ROC-AUC Class {class_idx}", roc_auc, epoch)

    # return metrics averaged over tasks and not averaged over tasks
    return np.mean(np.array(all_pr_auc)), np.mean(np.array(all_roc_auc)), np.array(all_pr_auc), np.array(all_roc_auc)

# %%
def compute_weighted_loss(y_pred, y_true):
    """
    Compute batch-wise weighted loss, giving equal influence to all targets.
    """
    # Create a mask for valid labels (non-NaN)
    mask = ~torch.isnan(y_true)  # True where valid

    # Count valid labels per target in the batch
    target_counts = mask.sum(dim=0)  # Number of valid samples per target in this batch
    # Avoid division by zero (replace 0 counts with 1)
    target_counts = target_counts.float().clamp(min=1)

    # Compute target-wise weights (Inverse of label frequency)
    target_weights = target_counts.max() / target_counts  # Higher weight for rare labels
    # Compute loss (Binary Cross-Entropy)
    criterion = torch.nn.BCEWithLogitsLoss(reduction='none')
    loss = criterion(y_pred, torch.nan_to_num(y_true, nan=0.0))  # Replace NaNs with 0 for loss computation

    # Apply target-wise weights (broadcasting)
    weighted_loss = loss * target_weights

    # Compute final loss (only averaging over valid elements)
    final_loss = torch.nanmean(weighted_loss)  # Ignore NaNs in loss calculation
    return final_loss

# not used
def masked_bce_loss(outputs, targets):
    mask = ~torch.isnan(targets)  # Create a mask where values are NOT NaN
    loss = nn.functional.binary_cross_entropy_with_logits(outputs[mask], targets[mask])  # Compute loss only on valid labels
    return loss

# %%
def save_best_model(model, avg_pr_auc, best_score, file_path):
    # Check if the current average PR AUC is better than the best recorded score
    if avg_pr_auc > best_score:
        torch.save(model.state_dict(), file_path)
        print(f"Saved new best model with avg PR AUC: {avg_pr_auc:.4f}")
        return True
    else:
        print(f"Current avg PR AUC: {avg_pr_auc:.4f} did not improve over best score: {best_score:.4f}")
        return False

# %%
# Function to train the model
def train_model(model, train_loader, val_loader, criterion, optimizer, device, writer, num_epochs=10, alpha=0.8):
    model.to(device)
    best_score = 0
    file_path = "best_model.pth"
    for epoch in range(num_epochs):
        # ------------- TRAINING ------------ #
        model.train()
        running_loss = 0.0
        all_labels_train = []
        all_preds_train = []

        for inputs, labels in train_loader:
            inputs = embedding_propagation(inputs, alpha) # calculate embeddings for inputs
            inputs, labels = inputs.view(inputs.size(0), -1).to(device), labels.to(device) # load inputs & labels onto gpu
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels) # criterion is loss fct passed to function, NaN values are masked there
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            # Store predictions & labels for AUC-PR computation
            all_labels_train.append(labels.detach().cpu().numpy())
            all_preds_train.append(torch.sigmoid(outputs).detach().cpu().numpy())  # Convert logits to probabilities

        # Compute training AUC-PR
        train_pr_auc, train_roc_auc, _, _ = getPrAucIndividualClass("Train", all_labels_train, all_preds_train, writer, epoch)
        epoch_loss_train = running_loss / len(train_loader)

        # log loss and auc-pr to tensorboard
        # writer.add_scalar("Loss/Training", epoch_loss_train, epoch)

        # --------- EVALUATION AFTER EPOCH --------------- #
        model.eval()
        val_loss = 0.0
        all_labels_val = []
        all_preds_val = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = embedding_propagation(inputs, alpha) # compute embeddings for inputs
                inputs, labels = inputs.to(device), labels.to(device) # load to gpu

                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                # Store predictions & labels for AUC-PR computation
                all_labels_val.append(labels.cpu().numpy())
                all_preds_val.append(torch.sigmoid(outputs).cpu().numpy())  # Convert logits to probabilities

        epoch_loss_val = val_loss / len(val_loader)

        # writer.add_scalar("Loss/Validation", epoch_loss_val, epoch) # tensorboard
        # Compute Validation metrics
        val_pr_auc, val_roc_auc, _, _ = getPrAucIndividualClass("Val", all_labels_val, all_preds_val, writer, epoch)
        # if better, store model
        saved = save_best_model(model, avg_pr_auc=val_pr_auc, best_score=best_score, file_path=file_path)
        if saved:
            best_score = val_pr_auc
        # ------------------- END of EPOCH STUFF ------------- #
        print(f"Epoch {epoch+1}/{num_epochs} | "
              f"Train Loss: {epoch_loss_train:.4f}, Avg Train AUC-PR: {train_pr_auc:.4f}, Avg Train AUC-ROC: {train_roc_auc:.4f} | "
              f"Val Loss: {epoch_loss_val:.4f}, Avg Val AUC-PR: {val_pr_auc:.4f}, Avg Val AUC-ROC: {val_roc_auc:.4f}"
        )
        
        # # Log model parameters and gradients to tensorboard
        # for name, param in model.named_parameters():
        #     writer.add_histogram(name, param, epoch)
        #     writer.add_histogram(f"{name}.grad", param.grad, epoch)
        # # log model architecture
        # writer.add_graph(model, torch.randn(1, 2248).to(device))
    
    # ----------- EVALUATE BEST MODEL ------------- #
    model.load_state_dict(torch.load(file_path, map_location=device)) # load best model
    model.eval()
    val_loss = 0.0
    all_labels_val = []
    all_preds_val = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs = embedding_propagation(inputs, alpha) # compute embeddings for inputs
            inputs, labels = inputs.to(device), labels.to(device) # load input & labels onto gpu

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            # Store predictions & labels for AUC-PR computation
            all_labels_val.append(labels.cpu().numpy())
            all_preds_val.append(torch.sigmoid(outputs).cpu().numpy())  # Convert logits to probabilities

    epoch_loss_val = val_loss / len(val_loader)
    # writer.add_scalar("Loss/Validation", epoch_loss_val, epoch) # tensorboard

    # Compute metrics for best model and return them
    val_pr_auc, val_roc_auc, val_pr_auc_per_task, val_roc_auc_per_task = getPrAucIndividualClass("Best Val", all_labels_val, all_preds_val, writer, epoch)
    print(f"Best Model Results | "
              f"Avg Val AUC-PR: {val_pr_auc:.4f}, Avg Val AUC-ROC: {val_roc_auc:.4f}"
              
        )
    return epoch_loss_val, val_pr_auc, val_roc_auc, val_pr_auc_per_task, val_roc_auc_per_task

# %%
# creae dataloaders
def get_datasets(X_train, y_train, X_val, y_val, X_test, y_test, seed):
    def worker_init_fn(worker_id):
        # Adjust the seed based on the worker id to ensure different seeds for each worker.
        np.random.seed(seed + worker_id)
        random.seed(seed + worker_id)

    batch_size = 120
    train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,worker_init_fn=worker_init_fn)

    val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True,worker_init_fn=worker_init_fn)

    test_dataset = TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32))
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, worker_init_fn=worker_init_fn)

    return train_loader, val_loader, test_loader

# %%
input_size = 2248 
hidden_sizes = [120, 48, None]
output_size = 9
alpha = 0.35
lr = 0.001
dropout_rates = [0.3, 0.5] # input dropout, hidden dropout
seeds = [8479, 227, 5413, 8179, 7528]

# list to collect results avg over task
avg_results = {
        "Delta-AUC-PR": [],
        "ROC-AUC": []
    }

# list to collect results per task
all_results = {
        "Delta-AUC-PR": [],
        "ROC-AUC": []
    } 

# train and evaluate model 5 times
for run in range(5):
    # set seed
    seed_value = seeds[run]
    torch.manual_seed(seed_value)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
    np.random.seed(seed_value)
    random.seed(seed_value)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)

    # initialize
    # writer = SummaryWriter(f"manual_runs/run_35_upsampling") # tensorboard
    writer = None
    model = NeuralNetwork(input_size, hidden_sizes, output_size, dropout_rates)
    criterion = compute_weighted_loss
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # train model
    train_loader, val_loader, test_loader = get_datasets(X_train, y_train, X_val, y_val, X_test, y_test, seed_value)
    val_loss, val_delta_auc_pr, val_roc_auc, val_pr_auc_per_task, val_roc_auc_per_task = train_model(model, train_loader, test_loader, criterion, optimizer, device, writer, num_epochs=20)
    
    # collect results
    avg_results["Delta-AUC-PR"].append(val_delta_auc_pr)
    avg_results["ROC-AUC"].append(val_roc_auc)

    all_results["Delta-AUC-PR"].append(np.array(val_pr_auc_per_task))
    all_results["ROC-AUC"].append(np.array(val_roc_auc_per_task))
    
    # ------- for hyperparameter tuning ------- #
    # val_loss, val_delta_auc_pr, val_roc_auc = train_model(model, train_loader, val_loader, criterion, optimizer, device, writer, num_epochs=20)

    # hparams = {
    #     "lr": lr,
    #     "batch_size": batch_size,
    #     "optimizer": "Adam",
    #     "hidden_sizes_1": hidden_sizes[0],
    #     "hidden_sizes_2": hidden_sizes[1]
    # }
    # metrics = {
    #     "auc-pr": val_delta_auc_pr,
    #     "loss": val_loss
    # }
    # writer.add_hparams(hparams, metrics)
    # writer.close()
# Out:
# cuda
# Saved new best model with avg PR AUC: 0.0695
# Epoch 1/20 | Train Loss: 0.0520, Avg Train AUC-PR: 0.0010, Avg Train AUC-ROC: 0.5493 | Val Loss: 0.0062, Avg Val AUC-PR: 0.0695, Avg Val AUC-ROC: 0.6655
# Saved new best model with avg PR AUC: 0.0702
# Epoch 2/20 | Train Loss: 0.0042, Avg Train AUC-PR: 0.0053, Avg Train AUC-ROC: 0.6754 | Val Loss: 0.0056, Avg Val AUC-PR: 0.0702, Avg Val AUC-ROC: 0.7159
# Current avg PR AUC: 0.0289 did not improve over best score: 0.0702
# Epoch 3/20 | Train Loss: 0.0034, Avg Train AUC-PR: 0.0204, Avg Train AUC-ROC: 0.8071 | Val Loss: 0.0051, Avg Val AUC-PR: 0.0289, Avg Val AUC-ROC: 0.7504
# Current avg PR AUC: 0.0124 did not improve over best score: 0.0702
# Epoch 4/20 | Train Loss: 0.0032, Avg Train AUC-PR: 0.0327, Avg Train AUC-ROC: 0.8544 | Val Loss: 0.0060, Avg Val AUC-PR: 0.0124, Avg Val AUC-ROC: 0.6552
# Current avg PR AUC: 0.0161 did not improve over best score: 0.0702
# Epoch 5/20 | Train Loss: 0.0031, Avg Train AUC-PR: 0.0530, Avg Train AUC-ROC: 0.8786 | Val Loss: 0.0064, Avg Val AUC-PR: 0.0161, Avg Val AUC-ROC: 0.6666
# Current avg PR AUC: 0.0157 did not improve over best score: 0.0702
# Epoch 6/20 | Train Loss: 0.0028, Avg Train AUC-PR: 0.0610, Avg Train AUC-ROC: 0.9114 | Val Loss: 0.0066, Avg Val AUC-PR: 0.0157, Avg Val AUC-ROC: 0.6804
# Current avg PR AUC: 0.0193 did not improve over best score: 0.0702
# Epoch 7/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0526, Avg Train AUC-ROC: 0.9131 | Val Loss: 0.0071, Avg Val AUC-PR: 0.0193, Avg Val AUC-ROC: 0.6359
# Current avg PR AUC: 0.0348 did not improve over best score: 0.0702
# Epoch 8/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0528, Avg Train AUC-ROC: 0.9113 | Val Loss: 0.0063, Avg Val AUC-PR: 0.0348, Avg Val AUC-ROC: 0.6795
# Current avg PR AUC: 0.0484 did not improve over best score: 0.0702
# Epoch 9/20 | Train Loss: 0.0029, Avg Train AUC-PR: 0.1047, Avg Train AUC-ROC: 0.9388 | Val Loss: 0.0065, Avg Val AUC-PR: 0.0484, Avg Val AUC-ROC: 0.7086
# Current avg PR AUC: 0.0129 did not improve over best score: 0.0702
# Epoch 10/20 | Train Loss: 0.0025, Avg Train AUC-PR: 0.1465, Avg Train AUC-ROC: 0.9490 | Val Loss: 0.0065, Avg Val AUC-PR: 0.0129, Avg Val AUC-ROC: 0.7171
# Current avg PR AUC: 0.0152 did not improve over best score: 0.0702
# Epoch 11/20 | Train Loss: 0.0023, Avg Train AUC-PR: 0.2179, Avg Train AUC-ROC: 0.9655 | Val Loss: 0.0073, Avg Val AUC-PR: 0.0152, Avg Val AUC-ROC: 0.7275
# Saved new best model with avg PR AUC: 0.0776
# Epoch 12/20 | Train Loss: 0.0024, Avg Train AUC-PR: 0.2143, Avg Train AUC-ROC: 0.9625 | Val Loss: 0.0070, Avg Val AUC-PR: 0.0776, Avg Val AUC-ROC: 0.7499
# Current avg PR AUC: 0.0513 did not improve over best score: 0.0776
# Epoch 13/20 | Train Loss: 0.0022, Avg Train AUC-PR: 0.2874, Avg Train AUC-ROC: 0.9714 | Val Loss: 0.0087, Avg Val AUC-PR: 0.0513, Avg Val AUC-ROC: 0.7002
# Saved new best model with avg PR AUC: 0.0785
# Epoch 14/20 | Train Loss: 0.0021, Avg Train AUC-PR: 0.2717, Avg Train AUC-ROC: 0.9792 | Val Loss: 0.0085, Avg Val AUC-PR: 0.0785, Avg Val AUC-ROC: 0.7185
# Saved new best model with avg PR AUC: 0.0792
# Epoch 15/20 | Train Loss: 0.0019, Avg Train AUC-PR: 0.3387, Avg Train AUC-ROC: 0.9838 | Val Loss: 0.0086, Avg Val AUC-PR: 0.0792, Avg Val AUC-ROC: 0.6855
# Current avg PR AUC: 0.0510 did not improve over best score: 0.0792
# Epoch 16/20 | Train Loss: 0.0019, Avg Train AUC-PR: 0.4010, Avg Train AUC-ROC: 0.9769 | Val Loss: 0.0086, Avg Val AUC-PR: 0.0510, Avg Val AUC-ROC: 0.6793
# Current avg PR AUC: 0.0497 did not improve over best score: 0.0792
# Epoch 17/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4513, Avg Train AUC-ROC: 0.9849 | Val Loss: 0.0093, Avg Val AUC-PR: 0.0497, Avg Val AUC-ROC: 0.6726
# Current avg PR AUC: 0.0413 did not improve over best score: 0.0792
# Epoch 18/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4599, Avg Train AUC-ROC: 0.9844 | Val Loss: 0.0112, Avg Val AUC-PR: 0.0413, Avg Val AUC-ROC: 0.6465
# Current avg PR AUC: 0.0157 did not improve over best score: 0.0792
# Epoch 19/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4543, Avg Train AUC-ROC: 0.9895 | Val Loss: 0.0107, Avg Val AUC-PR: 0.0157, Avg Val AUC-ROC: 0.7052
# Current avg PR AUC: 0.0335 did not improve over best score: 0.0792
# Epoch 20/20 | Train Loss: 0.0017, Avg Train AUC-PR: 0.5356, Avg Train AUC-ROC: 0.9872 | Val Loss: 0.0102, Avg Val AUC-PR: 0.0335, Avg Val AUC-ROC: 0.6833
# Best Model Results | Avg Val AUC-PR: 0.0799, Avg Val AUC-ROC: 0.7417
# cuda
# Saved new best model with avg PR AUC: 0.0318
# Epoch 1/20 | Train Loss: 0.0515, Avg Train AUC-PR: 0.0010, Avg Train AUC-ROC: 0.5457 | Val Loss: 0.0063, Avg Val AUC-PR: 0.0318, Avg Val AUC-ROC: 0.5680
# Saved new best model with avg PR AUC: 0.0321
# Epoch 2/20 | Train Loss: 0.0038, Avg Train AUC-PR: 0.0089, Avg Train AUC-ROC: 0.7196 | Val Loss: 0.0057, Avg Val AUC-PR: 0.0321, Avg Val AUC-ROC: 0.6364
# Saved new best model with avg PR AUC: 0.0401
# Epoch 3/20 | Train Loss: 0.0035, Avg Train AUC-PR: 0.0192, Avg Train AUC-ROC: 0.8227 | Val Loss: 0.0057, Avg Val AUC-PR: 0.0401, Avg Val AUC-ROC: 0.6812
# Current avg PR AUC: 0.0183 did not improve over best score: 0.0401
# Epoch 4/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0315, Avg Train AUC-ROC: 0.8862 | Val Loss: 0.0061, Avg Val AUC-PR: 0.0183, Avg Val AUC-ROC: 0.7142
# Saved new best model with avg PR AUC: 0.0655
# Epoch 5/20 | Train Loss: 0.0031, Avg Train AUC-PR: 0.0630, Avg Train AUC-ROC: 0.8835 | Val Loss: 0.0059, Avg Val AUC-PR: 0.0655, Avg Val AUC-ROC: 0.7397
# Current avg PR AUC: 0.0504 did not improve over best score: 0.0655
# Epoch 6/20 | Train Loss: 0.0029, Avg Train AUC-PR: 0.0666, Avg Train AUC-ROC: 0.9064 | Val Loss: 0.0056, Avg Val AUC-PR: 0.0504, Avg Val AUC-ROC: 0.6996
# Current avg PR AUC: 0.0204 did not improve over best score: 0.0655
# Epoch 7/20 | Train Loss: 0.0028, Avg Train AUC-PR: 0.0688, Avg Train AUC-ROC: 0.9257 | Val Loss: 0.0054, Avg Val AUC-PR: 0.0204, Avg Val AUC-ROC: 0.7050
# Current avg PR AUC: 0.0343 did not improve over best score: 0.0655
# Epoch 8/20 | Train Loss: 0.0028, Avg Train AUC-PR: 0.0799, Avg Train AUC-ROC: 0.9155 | Val Loss: 0.0060, Avg Val AUC-PR: 0.0343, Avg Val AUC-ROC: 0.6812
# Current avg PR AUC: 0.0498 did not improve over best score: 0.0655
# Epoch 9/20 | Train Loss: 0.0026, Avg Train AUC-PR: 0.1311, Avg Train AUC-ROC: 0.9397 | Val Loss: 0.0071, Avg Val AUC-PR: 0.0498, Avg Val AUC-ROC: 0.7301
# Saved new best model with avg PR AUC: 0.0774
# Epoch 10/20 | Train Loss: 0.0026, Avg Train AUC-PR: 0.1307, Avg Train AUC-ROC: 0.9604 | Val Loss: 0.0070, Avg Val AUC-PR: 0.0774, Avg Val AUC-ROC: 0.6812
# Current avg PR AUC: 0.0217 did not improve over best score: 0.0774
# Epoch 11/20 | Train Loss: 0.0023, Avg Train AUC-PR: 0.1893, Avg Train AUC-ROC: 0.9636 | Val Loss: 0.0076, Avg Val AUC-PR: 0.0217, Avg Val AUC-ROC: 0.6221
# Current avg PR AUC: 0.0689 did not improve over best score: 0.0774
# Epoch 12/20 | Train Loss: 0.0021, Avg Train AUC-PR: 0.2762, Avg Train AUC-ROC: 0.9799 | Val Loss: 0.0078, Avg Val AUC-PR: 0.0689, Avg Val AUC-ROC: 0.6740
# Current avg PR AUC: 0.0605 did not improve over best score: 0.0774
# Epoch 13/20 | Train Loss: 0.0020, Avg Train AUC-PR: 0.3322, Avg Train AUC-ROC: 0.9796 | Val Loss: 0.0082, Avg Val AUC-PR: 0.0605, Avg Val AUC-ROC: 0.6967
# Saved new best model with avg PR AUC: 0.0823
# Epoch 14/20 | Train Loss: 0.0021, Avg Train AUC-PR: 0.2691, Avg Train AUC-ROC: 0.9782 | Val Loss: 0.0078, Avg Val AUC-PR: 0.0823, Avg Val AUC-ROC: 0.6946
# Current avg PR AUC: 0.0777 did not improve over best score: 0.0823
# Epoch 15/20 | Train Loss: 0.0020, Avg Train AUC-PR: 0.4175, Avg Train AUC-ROC: 0.9813 | Val Loss: 0.0084, Avg Val AUC-PR: 0.0777, Avg Val AUC-ROC: 0.6940
# Current avg PR AUC: 0.0808 did not improve over best score: 0.0823
# Epoch 16/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4243, Avg Train AUC-ROC: 0.9868 | Val Loss: 0.0095, Avg Val AUC-PR: 0.0808, Avg Val AUC-ROC: 0.7496
# Saved new best model with avg PR AUC: 0.1104
# Epoch 17/20 | Train Loss: 0.0017, Avg Train AUC-PR: 0.4706, Avg Train AUC-ROC: 0.9875 | Val Loss: 0.0088, Avg Val AUC-PR: 0.1104, Avg Val AUC-ROC: 0.7443
# Current avg PR AUC: 0.0684 did not improve over best score: 0.1104
# Epoch 18/20 | Train Loss: 0.0017, Avg Train AUC-PR: 0.4781, Avg Train AUC-ROC: 0.9866 | Val Loss: 0.0104, Avg Val AUC-PR: 0.0684, Avg Val AUC-ROC: 0.6961
# Current avg PR AUC: 0.0367 did not improve over best score: 0.1104
# Epoch 19/20 | Train Loss: 0.0017, Avg Train AUC-PR: 0.4539, Avg Train AUC-ROC: 0.9849 | Val Loss: 0.0101, Avg Val AUC-PR: 0.0367, Avg Val AUC-ROC: 0.6567
# Current avg PR AUC: 0.0734 did not improve over best score: 0.1104
# Epoch 20/20 | Train Loss: 0.0017, Avg Train AUC-PR: 0.4894, Avg Train AUC-ROC: 0.9908 | Val Loss: 0.0105, Avg Val AUC-PR: 0.0734, Avg Val AUC-ROC: 0.6480
# Best Model Results | Avg Val AUC-PR: 0.0824, Avg Val AUC-ROC: 0.6884
# cuda
# Saved new best model with avg PR AUC: 0.0039
# Epoch 1/20 | Train Loss: 0.0591, Avg Train AUC-PR: 0.0073, Avg Train AUC-ROC: 0.5420 | Val Loss: 0.0068, Avg Val AUC-PR: 0.0039, Avg Val AUC-ROC: 0.5982
# Saved new best model with avg PR AUC: 0.0081
# Epoch 2/20 | Train Loss: 0.0040, Avg Train AUC-PR: 0.0072, Avg Train AUC-ROC: 0.7196 | Val Loss: 0.0062, Avg Val AUC-PR: 0.0081, Avg Val AUC-ROC: 0.6438
# Saved new best model with avg PR AUC: 0.0449
# Epoch 3/20 | Train Loss: 0.0033, Avg Train AUC-PR: 0.0376, Avg Train AUC-ROC: 0.8511 | Val Loss: 0.0062, Avg Val AUC-PR: 0.0449, Avg Val AUC-ROC: 0.6428
# Current avg PR AUC: 0.0372 did not improve over best score: 0.0449
# Epoch 4/20 | Train Loss: 0.0032, Avg Train AUC-PR: 0.0333, Avg Train AUC-ROC: 0.8792 | Val Loss: 0.0064, Avg Val AUC-PR: 0.0372, Avg Val AUC-ROC: 0.6958
# Current avg PR AUC: 0.0393 did not improve over best score: 0.0449
# Epoch 5/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0448, Avg Train AUC-ROC: 0.8878 | Val Loss: 0.0070, Avg Val AUC-PR: 0.0393, Avg Val AUC-ROC: 0.6582
# Saved new best model with avg PR AUC: 0.0457
# Epoch 6/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0540, Avg Train AUC-ROC: 0.9056 | Val Loss: 0.0062, Avg Val AUC-PR: 0.0457, Avg Val AUC-ROC: 0.6543
# Saved new best model with avg PR AUC: 0.0625
# Epoch 7/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0593, Avg Train AUC-ROC: 0.9275 | Val Loss: 0.0069, Avg Val AUC-PR: 0.0625, Avg Val AUC-ROC: 0.6794
# Saved new best model with avg PR AUC: 0.0655
# Epoch 8/20 | Train Loss: 0.0028, Avg Train AUC-PR: 0.0790, Avg Train AUC-ROC: 0.9276 | Val Loss: 0.0064, Avg Val AUC-PR: 0.0655, Avg Val AUC-ROC: 0.7021
# Saved new best model with avg PR AUC: 0.0789
# Epoch 9/20 | Train Loss: 0.0028, Avg Train AUC-PR: 0.1122, Avg Train AUC-ROC: 0.9304 | Val Loss: 0.0069, Avg Val AUC-PR: 0.0789, Avg Val AUC-ROC: 0.7092
# Current avg PR AUC: 0.0528 did not improve over best score: 0.0789
# Epoch 10/20 | Train Loss: 0.0025, Avg Train AUC-PR: 0.1366, Avg Train AUC-ROC: 0.9562 | Val Loss: 0.0071, Avg Val AUC-PR: 0.0528, Avg Val AUC-ROC: 0.6335
# Current avg PR AUC: 0.0344 did not improve over best score: 0.0789
# Epoch 11/20 | Train Loss: 0.0024, Avg Train AUC-PR: 0.2237, Avg Train AUC-ROC: 0.9659 | Val Loss: 0.0075, Avg Val AUC-PR: 0.0344, Avg Val AUC-ROC: 0.6817
# Current avg PR AUC: 0.0692 did not improve over best score: 0.0789
# Epoch 12/20 | Train Loss: 0.0023, Avg Train AUC-PR: 0.1954, Avg Train AUC-ROC: 0.9645 | Val Loss: 0.0072, Avg Val AUC-PR: 0.0692, Avg Val AUC-ROC: 0.6893
# Current avg PR AUC: 0.0601 did not improve over best score: 0.0789
# Epoch 13/20 | Train Loss: 0.0020, Avg Train AUC-PR: 0.3669, Avg Train AUC-ROC: 0.9732 | Val Loss: 0.0076, Avg Val AUC-PR: 0.0601, Avg Val AUC-ROC: 0.6797
# Current avg PR AUC: 0.0544 did not improve over best score: 0.0789
# Epoch 14/20 | Train Loss: 0.0020, Avg Train AUC-PR: 0.2713, Avg Train AUC-ROC: 0.9832 | Val Loss: 0.0079, Avg Val AUC-PR: 0.0544, Avg Val AUC-ROC: 0.7191
# Current avg PR AUC: 0.0344 did not improve over best score: 0.0789
# Epoch 15/20 | Train Loss: 0.0020, Avg Train AUC-PR: 0.3569, Avg Train AUC-ROC: 0.9794 | Val Loss: 0.0093, Avg Val AUC-PR: 0.0344, Avg Val AUC-ROC: 0.6292
# Current avg PR AUC: 0.0677 did not improve over best score: 0.0789
# Epoch 16/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.3916, Avg Train AUC-ROC: 0.9839 | Val Loss: 0.0083, Avg Val AUC-PR: 0.0677, Avg Val AUC-ROC: 0.6774
# Current avg PR AUC: 0.0316 did not improve over best score: 0.0789
# Epoch 17/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4696, Avg Train AUC-ROC: 0.9848 | Val Loss: 0.0086, Avg Val AUC-PR: 0.0316, Avg Val AUC-ROC: 0.7038
# Current avg PR AUC: 0.0556 did not improve over best score: 0.0789
# Epoch 18/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4401, Avg Train AUC-ROC: 0.9886 | Val Loss: 0.0086, Avg Val AUC-PR: 0.0556, Avg Val AUC-ROC: 0.7084
# Current avg PR AUC: 0.0329 did not improve over best score: 0.0789
# Epoch 19/20 | Train Loss: 0.0015, Avg Train AUC-PR: 0.4979, Avg Train AUC-ROC: 0.9942 | Val Loss: 0.0102, Avg Val AUC-PR: 0.0329, Avg Val AUC-ROC: 0.6884
# Current avg PR AUC: 0.0301 did not improve over best score: 0.0789
# Epoch 20/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4818, Avg Train AUC-ROC: 0.9854 | Val Loss: 0.0096, Avg Val AUC-PR: 0.0301, Avg Val AUC-ROC: 0.6963
# Best Model Results | Avg Val AUC-PR: 0.0508, Avg Val AUC-ROC: 0.6344
# cuda
# Saved new best model with avg PR AUC: 0.0050
# Epoch 1/20 | Train Loss: 0.0587, Avg Train AUC-PR: 0.0003, Avg Train AUC-ROC: 0.5199 | Val Loss: 0.0068, Avg Val AUC-PR: 0.0050, Avg Val AUC-ROC: 0.5861
# Saved new best model with avg PR AUC: 0.0125
# Epoch 2/20 | Train Loss: 0.0041, Avg Train AUC-PR: 0.0064, Avg Train AUC-ROC: 0.7022 | Val Loss: 0.0062, Avg Val AUC-PR: 0.0125, Avg Val AUC-ROC: 0.6113
# Saved new best model with avg PR AUC: 0.0165
# Epoch 3/20 | Train Loss: 0.0034, Avg Train AUC-PR: 0.0196, Avg Train AUC-ROC: 0.8343 | Val Loss: 0.0057, Avg Val AUC-PR: 0.0165, Avg Val AUC-ROC: 0.7170
# Current avg PR AUC: 0.0084 did not improve over best score: 0.0165
# Epoch 4/20 | Train Loss: 0.0033, Avg Train AUC-PR: 0.0327, Avg Train AUC-ROC: 0.8701 | Val Loss: 0.0055, Avg Val AUC-PR: 0.0084, Avg Val AUC-ROC: 0.7313
# Saved new best model with avg PR AUC: 0.0472
# Epoch 5/20 | Train Loss: 0.0031, Avg Train AUC-PR: 0.0502, Avg Train AUC-ROC: 0.8952 | Val Loss: 0.0065, Avg Val AUC-PR: 0.0472, Avg Val AUC-ROC: 0.6552
# Current avg PR AUC: 0.0424 did not improve over best score: 0.0472
# Epoch 6/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0370, Avg Train AUC-ROC: 0.9024 | Val Loss: 0.0057, Avg Val AUC-PR: 0.0424, Avg Val AUC-ROC: 0.6492
# Current avg PR AUC: 0.0359 did not improve over best score: 0.0472
# Epoch 7/20 | Train Loss: 0.0029, Avg Train AUC-PR: 0.0708, Avg Train AUC-ROC: 0.9160 | Val Loss: 0.0069, Avg Val AUC-PR: 0.0359, Avg Val AUC-ROC: 0.6619
# Saved new best model with avg PR AUC: 0.0559
# Epoch 8/20 | Train Loss: 0.0029, Avg Train AUC-PR: 0.0941, Avg Train AUC-ROC: 0.9240 | Val Loss: 0.0074, Avg Val AUC-PR: 0.0559, Avg Val AUC-ROC: 0.6209
# Current avg PR AUC: 0.0508 did not improve over best score: 0.0559
# Epoch 9/20 | Train Loss: 0.0025, Avg Train AUC-PR: 0.1165, Avg Train AUC-ROC: 0.9494 | Val Loss: 0.0064, Avg Val AUC-PR: 0.0508, Avg Val AUC-ROC: 0.6731
# Current avg PR AUC: 0.0523 did not improve over best score: 0.0559
# Epoch 10/20 | Train Loss: 0.0024, Avg Train AUC-PR: 0.1519, Avg Train AUC-ROC: 0.9577 | Val Loss: 0.0070, Avg Val AUC-PR: 0.0523, Avg Val AUC-ROC: 0.6694
# Current avg PR AUC: 0.0375 did not improve over best score: 0.0559
# Epoch 11/20 | Train Loss: 0.0023, Avg Train AUC-PR: 0.2182, Avg Train AUC-ROC: 0.9703 | Val Loss: 0.0077, Avg Val AUC-PR: 0.0375, Avg Val AUC-ROC: 0.6394
# Current avg PR AUC: 0.0269 did not improve over best score: 0.0559
# Epoch 12/20 | Train Loss: 0.0022, Avg Train AUC-PR: 0.2712, Avg Train AUC-ROC: 0.9667 | Val Loss: 0.0077, Avg Val AUC-PR: 0.0269, Avg Val AUC-ROC: 0.7043
# Current avg PR AUC: 0.0292 did not improve over best score: 0.0559
# Epoch 13/20 | Train Loss: 0.0020, Avg Train AUC-PR: 0.2597, Avg Train AUC-ROC: 0.9816 | Val Loss: 0.0083, Avg Val AUC-PR: 0.0292, Avg Val AUC-ROC: 0.6499
# Saved new best model with avg PR AUC: 0.0578
# Epoch 14/20 | Train Loss: 0.0019, Avg Train AUC-PR: 0.3955, Avg Train AUC-ROC: 0.9828 | Val Loss: 0.0102, Avg Val AUC-PR: 0.0578, Avg Val AUC-ROC: 0.6383
# Current avg PR AUC: 0.0576 did not improve over best score: 0.0578
# Epoch 15/20 | Train Loss: 0.0021, Avg Train AUC-PR: 0.3232, Avg Train AUC-ROC: 0.9792 | Val Loss: 0.0103, Avg Val AUC-PR: 0.0576, Avg Val AUC-ROC: 0.6609
# Saved new best model with avg PR AUC: 0.0623
# Epoch 16/20 | Train Loss: 0.0020, Avg Train AUC-PR: 0.4172, Avg Train AUC-ROC: 0.9826 | Val Loss: 0.0101, Avg Val AUC-PR: 0.0623, Avg Val AUC-ROC: 0.6579
# Current avg PR AUC: 0.0424 did not improve over best score: 0.0623
# Epoch 17/20 | Train Loss: 0.0016, Avg Train AUC-PR: 0.4903, Avg Train AUC-ROC: 0.9879 | Val Loss: 0.0099, Avg Val AUC-PR: 0.0424, Avg Val AUC-ROC: 0.6984
# Saved new best model with avg PR AUC: 0.0748
# Epoch 18/20 | Train Loss: 0.0019, Avg Train AUC-PR: 0.4441, Avg Train AUC-ROC: 0.9832 | Val Loss: 0.0095, Avg Val AUC-PR: 0.0748, Avg Val AUC-ROC: 0.6365
# Current avg PR AUC: 0.0264 did not improve over best score: 0.0748
# Epoch 19/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4938, Avg Train AUC-ROC: 0.9861 | Val Loss: 0.0110, Avg Val AUC-PR: 0.0264, Avg Val AUC-ROC: 0.6343
# Current avg PR AUC: 0.0276 did not improve over best score: 0.0748
# Epoch 20/20 | Train Loss: 0.0015, Avg Train AUC-PR: 0.5518, Avg Train AUC-ROC: 0.9883 | Val Loss: 0.0100, Avg Val AUC-PR: 0.0276, Avg Val AUC-ROC: 0.6517
# Best Model Results | Avg Val AUC-PR: 0.0808, Avg Val AUC-ROC: 0.7209
# cuda
# Saved new best model with avg PR AUC: 0.0321
# Epoch 1/20 | Train Loss: 0.0485, Avg Train AUC-PR: 0.0012, Avg Train AUC-ROC: 0.5355 | Val Loss: 0.0064, Avg Val AUC-PR: 0.0321, Avg Val AUC-ROC: 0.5780
# Saved new best model with avg PR AUC: 0.0355
# Epoch 2/20 | Train Loss: 0.0038, Avg Train AUC-PR: 0.0056, Avg Train AUC-ROC: 0.7440 | Val Loss: 0.0059, Avg Val AUC-PR: 0.0355, Avg Val AUC-ROC: 0.6493
# Saved new best model with avg PR AUC: 0.0491
# Epoch 3/20 | Train Loss: 0.0033, Avg Train AUC-PR: 0.0228, Avg Train AUC-ROC: 0.8449 | Val Loss: 0.0059, Avg Val AUC-PR: 0.0491, Avg Val AUC-ROC: 0.7272
# Current avg PR AUC: 0.0487 did not improve over best score: 0.0491
# Epoch 4/20 | Train Loss: 0.0032, Avg Train AUC-PR: 0.0315, Avg Train AUC-ROC: 0.8702 | Val Loss: 0.0063, Avg Val AUC-PR: 0.0487, Avg Val AUC-ROC: 0.6633
# Current avg PR AUC: 0.0178 did not improve over best score: 0.0491
# Epoch 5/20 | Train Loss: 0.0033, Avg Train AUC-PR: 0.0490, Avg Train AUC-ROC: 0.8575 | Val Loss: 0.0062, Avg Val AUC-PR: 0.0178, Avg Val AUC-ROC: 0.6775
# Current avg PR AUC: 0.0219 did not improve over best score: 0.0491
# Epoch 6/20 | Train Loss: 0.0030, Avg Train AUC-PR: 0.0479, Avg Train AUC-ROC: 0.9008 | Val Loss: 0.0065, Avg Val AUC-PR: 0.0219, Avg Val AUC-ROC: 0.6655
# Saved new best model with avg PR AUC: 0.0683
# Epoch 7/20 | Train Loss: 0.0031, Avg Train AUC-PR: 0.0699, Avg Train AUC-ROC: 0.9081 | Val Loss: 0.0060, Avg Val AUC-PR: 0.0683, Avg Val AUC-ROC: 0.7129
# Saved new best model with avg PR AUC: 0.1015
# Epoch 8/20 | Train Loss: 0.0028, Avg Train AUC-PR: 0.1193, Avg Train AUC-ROC: 0.9270 | Val Loss: 0.0066, Avg Val AUC-PR: 0.1015, Avg Val AUC-ROC: 0.7294
# Current avg PR AUC: 0.0494 did not improve over best score: 0.1015
# Epoch 9/20 | Train Loss: 0.0025, Avg Train AUC-PR: 0.1481, Avg Train AUC-ROC: 0.9493 | Val Loss: 0.0066, Avg Val AUC-PR: 0.0494, Avg Val AUC-ROC: 0.7502
# Current avg PR AUC: 0.0319 did not improve over best score: 0.1015
# Epoch 10/20 | Train Loss: 0.0026, Avg Train AUC-PR: 0.1211, Avg Train AUC-ROC: 0.9496 | Val Loss: 0.0069, Avg Val AUC-PR: 0.0319, Avg Val AUC-ROC: 0.6538
# Current avg PR AUC: 0.0739 did not improve over best score: 0.1015
# Epoch 11/20 | Train Loss: 0.0024, Avg Train AUC-PR: 0.2250, Avg Train AUC-ROC: 0.9625 | Val Loss: 0.0060, Avg Val AUC-PR: 0.0739, Avg Val AUC-ROC: 0.7689
# Current avg PR AUC: 0.0840 did not improve over best score: 0.1015
# Epoch 12/20 | Train Loss: 0.0022, Avg Train AUC-PR: 0.2228, Avg Train AUC-ROC: 0.9755 | Val Loss: 0.0075, Avg Val AUC-PR: 0.0840, Avg Val AUC-ROC: 0.7652
# Current avg PR AUC: 0.0626 did not improve over best score: 0.1015
# Epoch 13/20 | Train Loss: 0.0023, Avg Train AUC-PR: 0.2401, Avg Train AUC-ROC: 0.9719 | Val Loss: 0.0074, Avg Val AUC-PR: 0.0626, Avg Val AUC-ROC: 0.7237
# Current avg PR AUC: 0.0544 did not improve over best score: 0.1015
# Epoch 14/20 | Train Loss: 0.0021, Avg Train AUC-PR: 0.3528, Avg Train AUC-ROC: 0.9789 | Val Loss: 0.0080, Avg Val AUC-PR: 0.0544, Avg Val AUC-ROC: 0.7525
# Current avg PR AUC: 0.0748 did not improve over best score: 0.1015
# Epoch 15/20 | Train Loss: 0.0019, Avg Train AUC-PR: 0.4267, Avg Train AUC-ROC: 0.9829 | Val Loss: 0.0088, Avg Val AUC-PR: 0.0748, Avg Val AUC-ROC: 0.7414
# Current avg PR AUC: 0.0452 did not improve over best score: 0.1015
# Epoch 16/20 | Train Loss: 0.0019, Avg Train AUC-PR: 0.3403, Avg Train AUC-ROC: 0.9826 | Val Loss: 0.0094, Avg Val AUC-PR: 0.0452, Avg Val AUC-ROC: 0.7328
# Saved new best model with avg PR AUC: 0.1144
# Epoch 17/20 | Train Loss: 0.0017, Avg Train AUC-PR: 0.4968, Avg Train AUC-ROC: 0.9911 | Val Loss: 0.0091, Avg Val AUC-PR: 0.1144, Avg Val AUC-ROC: 0.7527
# Current avg PR AUC: 0.0375 did not improve over best score: 0.1144
# Epoch 18/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.4520, Avg Train AUC-ROC: 0.9880 | Val Loss: 0.0104, Avg Val AUC-PR: 0.0375, Avg Val AUC-ROC: 0.6638
# Current avg PR AUC: 0.0164 did not improve over best score: 0.1144
# Epoch 19/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.5250, Avg Train AUC-ROC: 0.9837 | Val Loss: 0.0106, Avg Val AUC-PR: 0.0164, Avg Val AUC-ROC: 0.6755
# Current avg PR AUC: 0.0230 did not improve over best score: 0.1144
# Epoch 20/20 | Train Loss: 0.0018, Avg Train AUC-PR: 0.5110, Avg Train AUC-ROC: 0.9817 | Val Loss: 0.0106, Avg Val AUC-PR: 0.0230, Avg Val AUC-ROC: 0.6401
# Best Model Results | Avg Val AUC-PR: 0.0368, Avg Val AUC-ROC: 0.7299

# %%
# calculate mean and sd for five runs but don't average over tasks
final_auc_pr = np.mean(np.array(avg_results["Delta-AUC-PR"]))
final_roc_auc = np.mean(np.array(avg_results["ROC-AUC"]))
final_sd_auc_pr = np.std(np.array(avg_results["Delta-AUC-PR"]))
final_sd_roc_auc = np.std(np.array(avg_results["ROC-AUC"]))

# save in json convertible format
final_results = [{
    "Delta-AUC-PR": float(final_auc_pr),
    "ROC-AUC": float(final_roc_auc),
    "Sd-Delta-AUC-PR": float(final_sd_auc_pr),
    "Sd-ROC-AUC": float(final_sd_roc_auc)
}]
final_results

# write to json file
with open("./metrics/metrics_pretraining_ep.json", "w") as f:
    json.dump(final_results, f, indent=4)

# %%
all_results = {
    key: [arr.tolist() if isinstance(arr, np.ndarray) else arr for arr in value]
    for key, value in all_results.items()
}

# %%
# calculate mean and sd for five runs but don't average over tasks
avg_auc_pr_per_task = np.mean(np.array(all_results["Delta-AUC-PR"]), axis=0)
sd_auc_pr_per_task = np.std(np.array(all_results["Delta-AUC-PR"]), axis=0)

avg_roc_auc_per_task = np.mean(np.array(all_results["ROC-AUC"]), axis=0)
sd_roc_auc_per_task = np.std(np.array(all_results["ROC-AUC"]), axis=0)

# save in json convertible format
final_results_per_task = [{
    "Delta-AUC-PR per task": list(avg_auc_pr_per_task),
    "ROC-AUC per task": list(avg_roc_auc_per_task),
    "Sd-Delta-AUC-PR per task": list(sd_auc_pr_per_task),
    "Sd-ROC-AUC per task": list(sd_roc_auc_per_task)
}]
final_results_per_task

# write to json file
with open("./metrics/metrics_pretraining_ep_per_task.json", "w") as f:
    json.dump(final_results_per_task, f, indent=4)

# %%
# calculate mean and sd for five runs but do average over tasks
avg_auc_pr_per_run = np.mean(np.array(all_results["Delta-AUC-PR"]), axis=1)
sd_auc_pr_per_run = np.std(np.array(all_results["Delta-AUC-PR"]), axis=1)

avg_roc_auc_per_run = np.mean(np.array(all_results["ROC-AUC"]), axis=1)
sd_roc_auc_per_run = np.std(np.array(all_results["ROC-AUC"]), axis=1)

# save in json convertible format
final_results_per_task = [{
    "Delta-AUC-PR per run": list(avg_auc_pr_per_run),
    "ROC-AUC per run": list(avg_roc_auc_per_run),
    "Sd-Delta-AUC-PR per run": list(sd_auc_pr_per_run),
    "Sd-ROC-AUC per run": list(sd_roc_auc_per_run)
}]
final_results_per_task

# write to json file
with open("./metrics/metrics_pretraining_ep_per_run.json", "w") as f:
    json.dump(final_results_per_task, f, indent=4)
